# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
representation_alignment_ave_1 = []
#representation_alignment_ave_2 = []
#output_weight_alignment_ave = []
weight_matrix_change_ave = []
#spectral_similarity_ave = []
#normalized_sensitivity_ave = []
#thresh_alignment_ave = []
#trans_k_m_alignment_ave = []
#trans_k_j_alignment_ave = []
#trans_r_j_alignment_ave = []
#a_j_alignment_ave = []
#transform_to_asc_r_alignment_ave = []
#hidden_weight_change_ave = []
Jacobian_change_norm_ave = []
#eff_weight_cos_sim_ave = []
#Jacobian_cos_sim_ave = []
effective_weight_change_norm_ave = []

# %%
file_name = '35'
Sigma_log = np.genfromtxt(f'./analysis/sigma_v/{file_name}/glifr_lheta_0_Sigma.csv', delimiter=',')
Sigma_log = Sigma_log/10.0

# %%
for Average in range(0, 3, 1):#6,8,1
    representation_alignment_log_1 = np.genfromtxt(f'./analysis/sigma_v/{file_name}/glifr_lheta_{Average}_RA.csv', delimiter=',')
    #representation_alignment_log_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_RA_2.csv', delimiter=',')
    weight_matrix_change_log =  np.genfromtxt(f'./analysis/sigma_v/{file_name}/glifr_lheta_{Average}_WMC.csv', delimiter=',')
    #output_weight_alignment_log =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_OWA.csv', delimiter=',')
    #spectral_similarity_log =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_SS.csv', delimiter=',')
    #normalized_sensitivity_log =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_NS.csv', delimiter=',')
    #trans_k_j_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_TKJA.csv', delimiter=',')
    #trans_r_j_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_TRJA.csv', delimiter=',')
    #a_j_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_AJA.csv', delimiter=',')
    #thresh_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_TA.csv', delimiter=',')
    #trans_k_m_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_TKMA.csv', delimiter=',')
    #transform_to_asc_r_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_TTARA.csv', delimiter=',')
    #hidden_weight_change_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_HWC.csv', delimiter=',')
    Jacobian_change_norm_log = np.genfromtxt(f'./analysis/sigma_v/{file_name}/glifr_lheta_{Average}_JCN.csv', delimiter=',')
    #eff_weight_cos_sim_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_EWCS.csv', delimiter=',')
    #Jacobian_cos_sim_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_JCS.csv', delimiter=',')
    effective_weight_change_norm_log = np.genfromtxt(f'./analysis/sigma_v/{file_name}/glifr_lheta_{Average}_EWCN.csv', delimiter=',')
    
    representation_alignment_ave_1.append(representation_alignment_log_1)
    #representation_alignment_ave_2.append(representation_alignment_log_2)
    #output_weight_alignment_ave.append(output_weight_alignment_log)
    weight_matrix_change_ave.append(weight_matrix_change_log)
    #spectral_similarity_ave.append(spectral_similarity_log)
    #normalized_sensitivity_ave.append(normalized_sensitivity_log)
    #thresh_alignment_ave.append(thresh_alignment_log)
    #trans_k_m_alignment_ave.append(trans_k_m_alignment_log)
    #trans_k_j_alignment_ave.append(trans_k_j_alignment_log)
    #trans_r_j_alignment_ave.append(trans_r_j_alignment_log)
    #a_j_alignment_ave.append(a_j_alignment_log)
    #transform_to_asc_r_alignment_ave.append(transform_to_asc_r_alignment_log)
    #hidden_weight_change_ave.append(hidden_weight_change_log)
    Jacobian_change_norm_ave.append(Jacobian_change_norm_log)
    #eff_weight_cos_sim_ave.append(eff_weight_cos_sim_log)
    #Jacobian_cos_sim_ave.append(Jacobian_cos_sim_log)
    effective_weight_change_norm_ave.append(effective_weight_change_norm_log)

# %%
#raa_1 = representation_alignment_ave_1
#raa_2 = representation_alignment_ave_2
#owaa = output_weight_alignment_ave
#wmca = weight_matrix_change_ave
#ssa = spectral_similarity_ave
#nsa = normalized_sensitivity_ave
#taa = thresh_alignment_ave
#tkmaa = trans_k_m_alignment_ave
#tkjaa = trans_k_j_alignment_ave
#trjaa = trans_r_j_alignment_ave
#ajaa = a_j_alignment_ave
#ttaraa = transform_to_asc_r_alignment_ave
#hwca = hidden_weight_change_ave
#jcna = Jacobian_change_norm_ave
#ewcsa = eff_weight_cos_sim_ave
#jcsa = Jacobian_cos_sim_ave
#ewcna = effective_weight_change_norm_ave

#raa_1 = np.mean(raa_1, axis=0)
raa_1 = np.mean(representation_alignment_ave_1, axis=0)
rastd_1 = np.std(representation_alignment_ave_1, axis=0)
#raa_2 = np.mean(raa_2, axis=0)
#owaa = np.mean(owaa, axis=0)
#wmca = np.mean(wmca, axis=0)
wmca = np.mean(weight_matrix_change_ave, axis=0)
wmcstd = np.std(weight_matrix_change_ave, axis=0)
#ssa = np.mean(ssa, axis=0)
#nsa = np.mean(nsa, axis=0)
#taa = np.mean(taa, axis=0)
#tkmaa = np.mean(tkmaa, axis=0)
#tkjaa = np.mean(tkjaa, axis=0)
#trjaa = np.mean(trjaa, axis=0)
#ajaa = np.mean(ajaa, axis=0)
#ttaraa = np.mean(ttaraa, axis=0)
#hwca = np.mean(hwca, axis=0)
#jcna = np.mean(jcna, axis=0)
jcna = np.mean(Jacobian_change_norm_ave, axis=0)
jcnstd = np.std(Jacobian_change_norm_ave, axis=0)
#ewcsa = np.mean(ewcsa, axis=0)
#jcsa = np.mean(jcsa, axis=0)
#ewcna = np.mean(ewcna, axis=0)
ewcna = np.mean(effective_weight_change_norm_ave, axis=0)
ewcnstd = np.std(effective_weight_change_norm_ave, axis=0)

# %%
plt.scatter(Sigma_log, raa_1, s=5, marker = "*", color='green')
plt.plot(Sigma_log, raa_1, label = 'Representation Similarity', linewidth = 1, color='green')
plt.errorbar(Sigma_log, raa_1, rastd_1, fmt ='o', mfc='green', mec='green', color='green', markersize=0.5)

#plt.scatter(Sigma_log, ewcsa, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, ewcsa, label = 'effective weight cosine similiarity', linewidth = 1, color='red')

#plt.scatter(Sigma_log, jcsa, s=5, marker = "*", color='blue')
#plt.plot(Sigma_log, jcsa, label = 'Jacobian cosine similiairity', linewidth = 1, color='blue')

#plt.scatter(Sigma_log, hwca/10, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, hwca/10, label = 'Hidden Weight Change/10', linewidth = 1, color='red')

#plt.scatter(Sigma_log, raa_2, s=5, marker = "*", color='purple')
#plt.plot(Sigma_log, raa_2, label = 'Cosine Similarity', linewidth = 1, color='purple')

#plt.scatter(Sigma_log, owaa/100, s=5, marker = "*", color='gray')
#plt.plot(Sigma_log, owaa/100, label = 'Linear Weight Norm', linewidth = 1, color='gray')

#plt.scatter(Sigma_log, wmaa/100, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, wmaa/100, label = 'Weight Matrix Norm', linewidth = 1, color='red')

#plt.scatter(Sigma_log, ssa, s=5, marker = "*", color='black')
#plt.plot(Sigma_log, ssa, label = 'Spectral Similarity', linewidth = 1, color='black')

#plt.scatter(Sigma_log, nsa, s=5, marker = "*", color='blue')
#plt.plot(Sigma_log, nsa, label = 'Normalized Sensitivity', linewidth = 1, color='blue')

plt.ylim(0,0.8)
#plt.ylim(0.4,0.7)

plt.xlabel('sigma')
plt.ylabel('linearity metrics')
plt.legend()
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')

# %%
plt.scatter(Sigma_log, wmca, s=5, marker = "*", color='green')
plt.plot(Sigma_log, wmca, label = 'Weight Change Norm', linewidth = 1, color='green')
plt.errorbar(Sigma_log, wmca, wmcstd, fmt ='o', mfc='green', mec='green', color='green', markersize=0.5)

#plt.scatter(Sigma_log, ewcsa, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, ewcsa, label = 'effective weight cosine similiarity', linewidth = 1, color='red')

#plt.scatter(Sigma_log, jcsa, s=5, marker = "*", color='blue')
#plt.plot(Sigma_log, jcsa, label = 'Jacobian cosine similiairity', linewidth = 1, color='blue')

#plt.scatter(Sigma_log, hwca/10, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, hwca/10, label = 'Hidden Weight Change/10', linewidth = 1, color='red')

#plt.scatter(Sigma_log, raa_2, s=5, marker = "*", color='purple')
#plt.plot(Sigma_log, raa_2, label = 'Cosine Similarity', linewidth = 1, color='purple')

#plt.scatter(Sigma_log, owaa/100, s=5, marker = "*", color='gray')
#plt.plot(Sigma_log, owaa/100, label = 'Linear Weight Norm', linewidth = 1, color='gray')

#plt.scatter(Sigma_log, wmaa/100, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, wmaa/100, label = 'Weight Matrix Norm', linewidth = 1, color='red')

#plt.scatter(Sigma_log, ssa, s=5, marker = "*", color='black')
#plt.plot(Sigma_log, ssa, label = 'Spectral Similarity', linewidth = 1, color='black')

#plt.scatter(Sigma_log, nsa, s=5, marker = "*", color='blue')
#plt.plot(Sigma_log, nsa, label = 'Normalized Sensitivity', linewidth = 1, color='blue')

#plt.ylim(0,0.8)

plt.xlabel('sigma')
plt.ylabel('linearity metrics')
plt.legend()
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')

# %%
#plt.scatter(Sigma_log, hwca, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, hwca, label = 'Hidden Weight Change', linewidth = 1, color='red')

#plt.scatter(Sigma_log, raa_2, s=5, marker = "*", color='purple')
#plt.plot(Sigma_log, raa_2, label = 'Representation Similarity_2', linewidth = 1, color='purple')

#plt.scatter(Sigma_log, owaa/100, s=5, marker = "*", color='gray')
#plt.plot(Sigma_log, owaa/100, label = 'Linear Weight Norm', linewidth = 1, color='gray')

plt.scatter(Sigma_log, ewcna, s=5, marker = "*", color='red')
plt.plot(Sigma_log, ewcna, label = 'Effective Weight Change Norm', linewidth = 1, color='red')
plt.errorbar(Sigma_log, ewcna, ewcnstd, fmt ='o', mfc='red', mec='red', color='red', markersize=0.5)

#plt.scatter(Sigma_log, ssa, s=5, marker = "*", color='black')
#plt.plot(Sigma_log, ssa, label = 'Spectral Similarity', linewidth = 1, color='black')

#plt.scatter(Sigma_log, nsa, s=5, marker = "*", color='blue')
#plt.plot(Sigma_log, nsa, label = 'Normalized Sensitivity', linewidth = 1, color='blue')

plt.xlabel('sigma_v')
plt.ylabel('linearity metrics')
plt.legend()
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')

# %%
plt.scatter(Sigma_log, jcna, s=5, marker = "*", color='red')
plt.plot(Sigma_log, jcna, label = 'Jacobian Change Norm', linewidth = 1, color='red')
plt.errorbar(Sigma_log, jcna, jcnstd, fmt ='o', mfc='red', mec='red', color='red', markersize=0.5)


#plt.scatter(Sigma_log, hwca/10, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, hwca/10, label = 'Hidden Weight Change/10', linewidth = 1, color='red')

#plt.scatter(Sigma_log, raa_2, s=5, marker = "*", color='purple')
#plt.plot(Sigma_log, raa_2, label = 'Cosine Similarity', linewidth = 1, color='purple')

#plt.scatter(Sigma_log, owaa/100, s=5, marker = "*", color='gray')
#plt.plot(Sigma_log, owaa/100, label = 'Linear Weight Norm', linewidth = 1, color='gray')

#plt.scatter(Sigma_log, wmaa/100, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, wmaa/100, label = 'Weight Matrix Norm', linewidth = 1, color='red')

#plt.scatter(Sigma_log, ssa, s=5, marker = "*", color='black')
#plt.plot(Sigma_log, ssa, label = 'Spectral Similarity', linewidth = 1, color='black')

#plt.scatter(Sigma_log, nsa, s=5, marker = "*", color='blue')
#plt.plot(Sigma_log, nsa, label = 'Normalized Sensitivity', linewidth = 1, color='blue')


plt.xlabel('sigma')
plt.ylabel('linearity metrics')
plt.legend()
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')

# %%
representation_alignment_ave_1 = []
#representation_alignment_ave_2 = []
#output_weight_alignment_ave = []
weight_matrix_change_ave = []
#spectral_similarity_ave = []
#normalized_sensitivity_ave = []
#thresh_alignment_ave = []
#trans_k_m_alignment_ave = []
#trans_k_j_alignment_ave = []
#trans_r_j_alignment_ave = []
#a_j_alignment_ave = []
#transform_to_asc_r_alignment_ave = []
#hidden_weight_change_ave = []
Jacobian_change_norm_ave = []
#eff_weight_cos_sim_ave = []
#Jacobian_cos_sim_ave = []
effective_weight_change_norm_ave = []

# %%
Sigma_log = np.genfromtxt(f'./analysis/sigma_v/{file_name}/glifr_rheta_0_Sigma.csv', delimiter=',')
Sigma_log = Sigma_log/10.0

# %%
for Average in range(0, 6, 1):
    representation_alignment_log_1 = np.genfromtxt(f'./analysis/sigma_v/{file_name}/glifr_rheta_{Average}_RA.csv', delimiter=',')
    #representation_alignment_log_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_RA_2.csv', delimiter=',')
    weight_matrix_change_log =  np.genfromtxt(f'./analysis/sigma_v/{file_name}/glifr_rheta_{Average}_WMC.csv', delimiter=',')
    #output_weight_alignment_log =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_OWA.csv', delimiter=',')
    #spectral_similarity_log =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_SS.csv', delimiter=',')
    #normalized_sensitivity_log =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_NS.csv', delimiter=',')
    #trans_k_j_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_TKJA.csv', delimiter=',')
    #trans_r_j_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_TRJA.csv', delimiter=',')
    #a_j_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_AJA.csv', delimiter=',')
    #thresh_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_TA.csv', delimiter=',')
    #trans_k_m_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_TKMA.csv', delimiter=',')
    #transform_to_asc_r_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_TTARA.csv', delimiter=',')
    #hidden_weight_change_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_HWC.csv', delimiter=',')
    Jacobian_change_norm_log = np.genfromtxt(f'./analysis/sigma_v/{file_name}/glifr_rheta_{Average}_JCN.csv', delimiter=',')
    #eff_weight_cos_sim_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_EWCS.csv', delimiter=',')
    #Jacobian_cos_sim_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_30/glifr_lheta_{Average}_JCS.csv', delimiter=',')
    effective_weight_change_norm_log = np.genfromtxt(f'./analysis/sigma_v/{file_name}/glifr_rheta_{Average}_EWCN.csv', delimiter=',')
    
    representation_alignment_ave_1.append(representation_alignment_log_1)
    #representation_alignment_ave_2.append(representation_alignment_log_2)
    #output_weight_alignment_ave.append(output_weight_alignment_log)
    weight_matrix_change_ave.append(weight_matrix_change_log)
    #spectral_similarity_ave.append(spectral_similarity_log)
    #normalized_sensitivity_ave.append(normalized_sensitivity_log)
    #thresh_alignment_ave.append(thresh_alignment_log)
    #trans_k_m_alignment_ave.append(trans_k_m_alignment_log)
    #trans_k_j_alignment_ave.append(trans_k_j_alignment_log)
    #trans_r_j_alignment_ave.append(trans_r_j_alignment_log)
    #a_j_alignment_ave.append(a_j_alignment_log)
    #transform_to_asc_r_alignment_ave.append(transform_to_asc_r_alignment_log)
    #hidden_weight_change_ave.append(hidden_weight_change_log)
    Jacobian_change_norm_ave.append(Jacobian_change_norm_log)
    #eff_weight_cos_sim_ave.append(eff_weight_cos_sim_log)
    #Jacobian_cos_sim_ave.append(Jacobian_cos_sim_log)
    effective_weight_change_norm_ave.append(effective_weight_change_norm_log)

# %%
#raa_1 = representation_alignment_ave_1
#raa_2 = representation_alignment_ave_2
#owaa = output_weight_alignment_ave
#wmca = weight_matrix_change_ave
#ssa = spectral_similarity_ave
#nsa = normalized_sensitivity_ave
#taa = thresh_alignment_ave
#tkmaa = trans_k_m_alignment_ave
#tkjaa = trans_k_j_alignment_ave
#trjaa = trans_r_j_alignment_ave
#ajaa = a_j_alignment_ave
#ttaraa = transform_to_asc_r_alignment_ave
#hwca = hidden_weight_change_ave
#jcna = Jacobian_change_norm_ave
#ewcsa = eff_weight_cos_sim_ave
#jcsa = Jacobian_cos_sim_ave
#ewcna = effective_weight_change_norm_ave

#raa_1 = np.mean(raa_1, axis=0)
raa_1 = np.mean(representation_alignment_ave_1, axis=0)
rastd_1 = np.std(representation_alignment_ave_1, axis=0)
#raa_2 = np.mean(raa_2, axis=0)
#owaa = np.mean(owaa, axis=0)
#wmca = np.mean(wmca, axis=0)
wmca = np.mean(weight_matrix_change_ave, axis=0)
wmcstd = np.std(weight_matrix_change_ave, axis=0)
#ssa = np.mean(ssa, axis=0)
#nsa = np.mean(nsa, axis=0)
#taa = np.mean(taa, axis=0)
#tkmaa = np.mean(tkmaa, axis=0)
#tkjaa = np.mean(tkjaa, axis=0)
#trjaa = np.mean(trjaa, axis=0)
#ajaa = np.mean(ajaa, axis=0)
#ttaraa = np.mean(ttaraa, axis=0)
#hwca = np.mean(hwca, axis=0)
#jcna = np.mean(jcna, axis=0)
jcna = np.mean(Jacobian_change_norm_ave, axis=0)
jcnstd = np.std(Jacobian_change_norm_ave, axis=0)
#ewcsa = np.mean(ewcsa, axis=0)
#jcsa = np.mean(jcsa, axis=0)
#ewcna = np.mean(ewcna, axis=0)
ewcna = np.mean(effective_weight_change_norm_ave, axis=0)
ewcnstd = np.std(effective_weight_change_norm_ave, axis=0)

# %%
plt.scatter(Sigma_log, raa_1, s=5, marker = "*", color='green')
plt.plot(Sigma_log, raa_1, label = 'Representation Similarity_1', linewidth = 1, color='green')
plt.errorbar(Sigma_log, raa_1, rastd_1, fmt ='o', mfc='green', mec='green', color='green', markersize=0.5)

#plt.scatter(Sigma_log, ewcsa, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, ewcsa, label = 'effective weight cosine similiarity', linewidth = 1, color='red')

#plt.scatter(Sigma_log, jcsa, s=5, marker = "*", color='blue')
#plt.plot(Sigma_log, jcsa, label = 'Jacobian cosine similiairity', linewidth = 1, color='blue')

#plt.scatter(Sigma_log, hwca/10, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, hwca/10, label = 'Hidden Weight Change/10', linewidth = 1, color='red')

#plt.scatter(Sigma_log, raa_2, s=5, marker = "*", color='purple')
#plt.plot(Sigma_log, raa_2, label = 'Cosine Similarity', linewidth = 1, color='purple')

#plt.scatter(Sigma_log, owaa/100, s=5, marker = "*", color='gray')
#plt.plot(Sigma_log, owaa/100, label = 'Linear Weight Norm', linewidth = 1, color='gray')

#plt.scatter(Sigma_log, wmaa/100, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, wmaa/100, label = 'Weight Matrix Norm', linewidth = 1, color='red')

#plt.scatter(Sigma_log, ssa, s=5, marker = "*", color='black')
#plt.plot(Sigma_log, ssa, label = 'Spectral Similarity', linewidth = 1, color='black')

#plt.scatter(Sigma_log, nsa, s=5, marker = "*", color='blue')
#plt.plot(Sigma_log, nsa, label = 'Normalized Sensitivity', linewidth = 1, color='blue')

plt.ylim(0,0.8)

plt.xlabel('sigma')
plt.ylabel('linearity metrics')
plt.legend()
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')

# %%
plt.scatter(Sigma_log, wmca, s=5, marker = "*", color='green')
plt.plot(Sigma_log, wmca, label = 'Weight Change Norm', linewidth = 1, color='green')
plt.errorbar(Sigma_log, wmca, wmcstd, fmt ='o', mfc='green', mec='green', color='green', markersize=0.5)

#plt.scatter(Sigma_log, ewcsa, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, ewcsa, label = 'effective weight cosine similiarity', linewidth = 1, color='red')

#plt.scatter(Sigma_log, jcsa, s=5, marker = "*", color='blue')
#plt.plot(Sigma_log, jcsa, label = 'Jacobian cosine similiairity', linewidth = 1, color='blue')

#plt.scatter(Sigma_log, hwca/10, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, hwca/10, label = 'Hidden Weight Change/10', linewidth = 1, color='red')

#plt.scatter(Sigma_log, raa_2, s=5, marker = "*", color='purple')
#plt.plot(Sigma_log, raa_2, label = 'Cosine Similarity', linewidth = 1, color='purple')

#plt.scatter(Sigma_log, owaa/100, s=5, marker = "*", color='gray')
#plt.plot(Sigma_log, owaa/100, label = 'Linear Weight Norm', linewidth = 1, color='gray')

#plt.scatter(Sigma_log, wmaa/100, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, wmaa/100, label = 'Weight Matrix Norm', linewidth = 1, color='red')

#plt.scatter(Sigma_log, ssa, s=5, marker = "*", color='black')
#plt.plot(Sigma_log, ssa, label = 'Spectral Similarity', linewidth = 1, color='black')

#plt.scatter(Sigma_log, nsa, s=5, marker = "*", color='blue')
#plt.plot(Sigma_log, nsa, label = 'Normalized Sensitivity', linewidth = 1, color='blue')

#plt.ylim(0,0.8)

plt.xlabel('sigma')
plt.ylabel('linearity metrics')
plt.legend()
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')

# %%
#plt.scatter(Sigma_log, hwca, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, hwca, label = 'Hidden Weight Change', linewidth = 1, color='red')

#plt.scatter(Sigma_log, raa_2, s=5, marker = "*", color='purple')
#plt.plot(Sigma_log, raa_2, label = 'Representation Similarity_2', linewidth = 1, color='purple')

#plt.scatter(Sigma_log, owaa/100, s=5, marker = "*", color='gray')
#plt.plot(Sigma_log, owaa/100, label = 'Linear Weight Norm', linewidth = 1, color='gray')

plt.scatter(Sigma_log, ewcna, s=5, marker = "*", color='red')
plt.plot(Sigma_log, ewcna, label = 'Effective Weight Change Norm', linewidth = 1, color='red')
plt.errorbar(Sigma_log, ewcna, ewcnstd, fmt ='o', mfc='red', mec='red', color='red', markersize=0.5)

#plt.scatter(Sigma_log, ssa, s=5, marker = "*", color='black')
#plt.plot(Sigma_log, ssa, label = 'Spectral Similarity', linewidth = 1, color='black')

#plt.scatter(Sigma_log, nsa, s=5, marker = "*", color='blue')
#plt.plot(Sigma_log, nsa, label = 'Normalized Sensitivity', linewidth = 1, color='blue')

plt.xlabel('sigma')
plt.ylabel('linearity metrics')
plt.legend()
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')

# %%
plt.scatter(Sigma_log, jcna, s=5, marker = "*", color='red')
plt.plot(Sigma_log, jcna, label = 'Jacobian Change Norm', linewidth = 1, color='red')
plt.errorbar(Sigma_log, jcna, jcnstd, fmt ='o', mfc='red', mec='red', color='red', markersize=0.5)


#plt.scatter(Sigma_log, hwca/10, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, hwca/10, label = 'Hidden Weight Change/10', linewidth = 1, color='red')

#plt.scatter(Sigma_log, raa_2, s=5, marker = "*", color='purple')
#plt.plot(Sigma_log, raa_2, label = 'Cosine Similarity', linewidth = 1, color='purple')

#plt.scatter(Sigma_log, owaa/100, s=5, marker = "*", color='gray')
#plt.plot(Sigma_log, owaa/100, label = 'Linear Weight Norm', linewidth = 1, color='gray')

#plt.scatter(Sigma_log, wmaa/100, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, wmaa/100, label = 'Weight Matrix Norm', linewidth = 1, color='red')

#plt.scatter(Sigma_log, ssa, s=5, marker = "*", color='black')
#plt.plot(Sigma_log, ssa, label = 'Spectral Similarity', linewidth = 1, color='black')

#plt.scatter(Sigma_log, nsa, s=5, marker = "*", color='blue')
#plt.plot(Sigma_log, nsa, label = 'Normalized Sensitivity', linewidth = 1, color='blue')


plt.xlabel('sigma')
plt.ylabel('linearity metrics')
plt.legend()
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')

# %%
representation_alignment_ave_1 = []
representation_alignment_ave_2 = []

effective_weight_change_norm_ave_1 = []
effective_weight_change_norm_ave_2 = []

# %%
file_name = '38'
Sigma_log = np.genfromtxt(f'./analysis/sigma_v/{file_name}/glifr_lheta_0_Sigma.csv', delimiter=',')
Sigma_log = Sigma_log/10.0

# %%
for Average in range(0, 6, 1):#6,8,1
    representation_alignment_log_1 = np.genfromtxt(f'./analysis/sigma_v/{file_name}/glifr_lheta_{Average}_RA.csv', delimiter=',')
    representation_alignment_log_2 = np.genfromtxt(f'./analysis/sigma_v/{file_name}/glifr_rheta_{Average}_RA.csv', delimiter=',')
    
    effective_weight_change_norm_log_1 = np.genfromtxt(f'./analysis/sigma_v/{file_name}/glifr_lheta_{Average}_EWCN.csv', delimiter=',')
    effective_weight_change_norm_log_2 = np.genfromtxt(f'./analysis/sigma_v/{file_name}/glifr_rheta_{Average}_EWCN.csv', delimiter=',')
    
    representation_alignment_ave_1.append(representation_alignment_log_1)
    representation_alignment_ave_2.append(representation_alignment_log_2)

    effective_weight_change_norm_ave_1.append(effective_weight_change_norm_log_1)
    effective_weight_change_norm_ave_2.append(effective_weight_change_norm_log_2)

# %%
raa_1 = np.mean(representation_alignment_ave_1, axis=0)
rastd_1 = np.std(representation_alignment_ave_1, axis=0)
raa_2 = np.mean(representation_alignment_ave_2, axis=0)
rastd_2 = np.std(representation_alignment_ave_2, axis=0)

ewcna_1 = np.mean(effective_weight_change_norm_ave_1, axis=0)
ewcnstd_1 = np.std(effective_weight_change_norm_ave_1, axis=0)
ewcna_2 = np.mean(effective_weight_change_norm_ave_2, axis=0)
ewcnstd_2 = np.std(effective_weight_change_norm_ave_2, axis=0)

# %%
plt.scatter(Sigma_log, raa_1, s=5, marker = "*", color='green')
plt.plot(Sigma_log, raa_1, label = 'Representation Similarity (homogeneous initialization)', linewidth = 1, color='green')
plt.errorbar(Sigma_log, raa_1, rastd_1, fmt ='o', mfc='green', mec='green', color='green', markersize=0.5)

plt.scatter(Sigma_log, raa_2, s=5, marker = "*", color='green')
plt.plot(Sigma_log, raa_2, label = 'Representation Similarity (heterogeneous initialization)', linewidth = 1, color='red')
plt.errorbar(Sigma_log, raa_2, rastd_2, fmt ='o', mfc='red', mec='red', color='red', markersize=0.5)

plt.ylim(0.3,0.8)

plt.xlabel('sigma_v')
plt.ylabel('linearity metrics')
plt.legend()
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')

# %%
plt.scatter(Sigma_log, ewcna_1, s=5, marker = "*", color='green')
plt.plot(Sigma_log, ewcna_1, label = 'Effective Weight Change Norm (homogeneous initialization)', linewidth = 1, color='green')
plt.errorbar(Sigma_log, ewcna_1, ewcnstd_1, fmt ='o', mfc='green', mec='green', color='green', markersize=0.5)

plt.scatter(Sigma_log, ewcna_2, s=5, marker = "*", color='red')
plt.plot(Sigma_log, ewcna_2, label = 'Effective Weight Change Norm (heterogeneous initialization)', linewidth = 1, color='red')
plt.errorbar(Sigma_log, ewcna_2, ewcnstd_2, fmt ='o', mfc='red', mec='red', color='red', markersize=0.5)

plt.xlabel('sigma_v')
plt.ylabel('linearity metrics')
plt.legend(loc="upper right")
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')

# %%
representation_alignment_ave_1 = []
representation_alignment_ave_2 = []
representation_alignment_ave_3 = []

effective_weight_change_norm_ave_1 = []
effective_weight_change_norm_ave_2 = []
effective_weight_change_norm_ave_3 = []

# %%
file_name_1 = '30'
file_name_2 = '33'
file_name_3 = '34'
Sigma_log_1 = np.genfromtxt(f'./analysis/sigma_v/{file_name_1}/glifr_lheta_0_Sigma.csv', delimiter=',')
Sigma_log_1 = Sigma_log_1/10.0
Sigma_log_2 = np.genfromtxt(f'./analysis/sigma_v/{file_name_2}/glifr_lheta_0_Sigma.csv', delimiter=',')
Sigma_log_2 = Sigma_log_2/10.0
Sigma_log_3 = np.genfromtxt(f'./analysis/sigma_v/{file_name_3}/glifr_lheta_0_Sigma.csv', delimiter=',')
Sigma_log_3 = Sigma_log_3/10.0

# %%
for Average in range(0, 6, 1):#6,8,1
    representation_alignment_log_1 = np.genfromtxt(f'./analysis/sigma_v/{file_name_1}/glifr_lheta_{Average}_RA.csv', delimiter=',')
    representation_alignment_log_2 = np.genfromtxt(f'./analysis/sigma_v/{file_name_2}/glifr_lheta_{Average}_RA.csv', delimiter=',')
    representation_alignment_log_3 = np.genfromtxt(f'./analysis/sigma_v/{file_name_3}/glifr_lheta_{Average}_RA.csv', delimiter=',')
    
    effective_weight_change_norm_log_1 = np.genfromtxt(f'./analysis/sigma_v/{file_name_1}/glifr_lheta_{Average}_EWCN.csv', delimiter=',')
    effective_weight_change_norm_log_2 = np.genfromtxt(f'./analysis/sigma_v/{file_name_2}/glifr_lheta_{Average}_EWCN.csv', delimiter=',')
    effective_weight_change_norm_log_3 = np.genfromtxt(f'./analysis/sigma_v/{file_name_3}/glifr_lheta_{Average}_EWCN.csv', delimiter=',')
    
    representation_alignment_ave_1.append(representation_alignment_log_1)
    representation_alignment_ave_2.append(representation_alignment_log_2)
    representation_alignment_ave_3.append(representation_alignment_log_3)

    effective_weight_change_norm_ave_1.append(effective_weight_change_norm_log_1)
    effective_weight_change_norm_ave_2.append(effective_weight_change_norm_log_2)
    effective_weight_change_norm_ave_3.append(effective_weight_change_norm_log_3)

# %%
raa_1 = np.mean(representation_alignment_ave_1, axis=0)
rastd_1 = np.std(representation_alignment_ave_1, axis=0)
raa_2 = np.mean(representation_alignment_ave_2, axis=0)
rastd_2 = np.std(representation_alignment_ave_2, axis=0)
raa_3 = np.mean(representation_alignment_ave_3, axis=0)
rastd_3 = np.std(representation_alignment_ave_3, axis=0)

ewcna_1 = np.mean(effective_weight_change_norm_ave_1, axis=0)
ewcnstd_1 = np.std(effective_weight_change_norm_ave_1, axis=0)
ewcna_2 = np.mean(effective_weight_change_norm_ave_2, axis=0)
ewcnstd_2 = np.std(effective_weight_change_norm_ave_2, axis=0)
ewcna_3 = np.mean(effective_weight_change_norm_ave_3, axis=0)
ewcnstd_3 = np.std(effective_weight_change_norm_ave_3, axis=0)

# %%
plt.scatter(Sigma_log_1, raa_1, s=5, marker = "*", color='green')
plt.plot(Sigma_log_1, raa_1, label = 'Representation Similarity (network size = 300)', linewidth = 1, color='green')
plt.errorbar(Sigma_log_1, raa_1, rastd_1, fmt ='o', mfc='green', mec='green', color='green', markersize=0.5)

plt.scatter(Sigma_log_2, raa_2, s=5, marker = "*", color='green')
plt.plot(Sigma_log_2, raa_2, label = 'Representation Similarity (network size = 600)', linewidth = 1, color='red')
plt.errorbar(Sigma_log_2, raa_2, rastd_2, fmt ='o', mfc='red', mec='red', color='red', markersize=0.5)

plt.scatter(Sigma_log_3, raa_3, s=5, marker = "*", color='blue')
plt.plot(Sigma_log_3, raa_3, label = 'Representation Similarity (network size = 1000)', linewidth = 1, color='blue')
plt.errorbar(Sigma_log_3, raa_3, rastd_3, fmt ='o', mfc='blue', mec='blue', color='blue', markersize=0.5)

plt.ylim(0,0.8)

plt.xlabel('sigma_v')
plt.ylabel('linearity metrics')
plt.legend()
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')

# %%
plt.scatter(Sigma_log_1, ewcna_1, s=5, marker = "*", color='green')
plt.plot(Sigma_log_1, ewcna_1, label = 'Effective Weight Change Norm (network size = 300)', linewidth = 1, color='green')
plt.errorbar(Sigma_log_1, ewcna_1, ewcnstd_1, fmt ='o', mfc='green', mec='green', color='green', markersize=0.5)

plt.scatter(Sigma_log_2, ewcna_2, s=5, marker = "*", color='red')
plt.plot(Sigma_log_2, ewcna_2, label = 'Effective Weight Change Norm (network size = 600)', linewidth = 1, color='red')
plt.errorbar(Sigma_log_2, ewcna_2, ewcnstd_2, fmt ='o', mfc='red', mec='red', color='red', markersize=0.5)

plt.scatter(Sigma_log_3, ewcna_3, s=5, marker = "*", color='blue')
plt.plot(Sigma_log_3, ewcna_3, label = 'Effective Weight Change Norm (network size = 1000)', linewidth = 1, color='blue')
plt.errorbar(Sigma_log_3, ewcna_3, ewcnstd_3, fmt ='o', mfc='blue', mec='blue', color='blue', markersize=0.5)

plt.xlabel('sigma_v')
plt.ylabel('linearity metrics')
plt.legend(loc="upper right")
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')

# %%
representation_alignment_ave_1 = []
representation_alignment_ave_2 = []
output_weight_alignment_ave = []
weight_matrix_alignment_ave = []
spectral_similarity_ave = []
normalized_sensitivity_ave = []
thresh_alignment_ave = []
trans_k_m_alignment_ave = []
trans_k_j_alignment_ave = []
trans_r_j_alignment_ave = []
a_j_alignment_ave = []
transform_to_asc_r_alignment_ave = []

# %%
Sigma_log = np.genfromtxt('./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_0_Sigma.csv', delimiter=',')
Sigma_log = Sigma_log/10.0

# %%
for Average in range(0, 8, 1):
    representation_alignment_log_1 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_RA_1.csv', delimiter=',')
    representation_alignment_log_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_RA_2.csv', delimiter=',')
    weight_matrix_alignment_log =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_WMA.csv', delimiter=',')
    output_weight_alignment_log =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_OWA.csv', delimiter=',')
    spectral_similarity_log =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_SS.csv', delimiter=',')
    normalized_sensitivity_log =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_NS.csv', delimiter=',')
    trans_k_j_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_TKJA.csv', delimiter=',')
    trans_r_j_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_TRJA.csv', delimiter=',')
    a_j_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_AJA.csv', delimiter=',')
    thresh_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_TA.csv', delimiter=',')
    trans_k_m_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_TKMA.csv', delimiter=',')
    transform_to_asc_r_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_TTARA.csv', delimiter=',')
    
    representation_alignment_ave_1.append(representation_alignment_log_1)
    representation_alignment_ave_2.append(representation_alignment_log_2)
    output_weight_alignment_ave.append(output_weight_alignment_log)
    weight_matrix_alignment_ave.append(weight_matrix_alignment_log)
    spectral_similarity_ave.append(spectral_similarity_log)
    normalized_sensitivity_ave.append(normalized_sensitivity_log)
    thresh_alignment_ave.append(thresh_alignment_log)
    trans_k_m_alignment_ave.append(trans_k_m_alignment_log)
    trans_k_j_alignment_ave.append(trans_k_j_alignment_log)
    trans_r_j_alignment_ave.append(trans_r_j_alignment_log)
    a_j_alignment_ave.append(a_j_alignment_log)
    transform_to_asc_r_alignment_ave.append(transform_to_asc_r_alignment_log)

# %%
raa_1 = representation_alignment_ave_1
raa_2 = representation_alignment_ave_2
owaa = output_weight_alignment_ave
wmaa = weight_matrix_alignment_ave
ssa = spectral_similarity_ave
nsa = normalized_sensitivity_ave
taa = thresh_alignment_ave
tkmaa = trans_k_m_alignment_ave
tkjaa = trans_k_j_alignment_ave
trjaa = trans_r_j_alignment_ave
ajaa = a_j_alignment_ave
ttaraa = transform_to_asc_r_alignment_ave

raa_1 = np.mean(raa_1, axis=0)
raa_2 = np.mean(raa_2, axis=0)
owaa = np.mean(owaa, axis=0)
wmaa = np.mean(wmaa, axis=0)
ssa = np.mean(ssa, axis=0)
nsa = np.mean(nsa, axis=0)
taa = np.mean(taa, axis=0)
tkmaa = np.mean(tkmaa, axis=0)
tkjaa = np.mean(tkjaa, axis=0)
trjaa = np.mean(trjaa, axis=0)
ajaa = np.mean(ajaa, axis=0)
ttaraa = np.mean(ttaraa, axis=0)

# %%
plt.scatter(Sigma_log, raa_1, s=5, marker = "*", color='green')
plt.plot(Sigma_log, raa_1, label = 'Representation Similarity_1', linewidth = 1, color='green')

#plt.scatter(Sigma_log, raa_2, s=5, marker = "*", color='purple')
#plt.plot(Sigma_log, raa_2, label = 'Representation Similarity_2', linewidth = 1, color='purple')

plt.scatter(Sigma_log, owaa/100, s=5, marker = "*", color='gray')
plt.plot(Sigma_log, owaa/100, label = 'Linear Weight Norm', linewidth = 1, color='gray')

plt.scatter(Sigma_log, wmaa/100, s=5, marker = "*", color='red')
plt.plot(Sigma_log, wmaa/100, label = 'Weight Matrix Norm', linewidth = 1, color='red')

plt.scatter(Sigma_log, ssa, s=5, marker = "*", color='black')
plt.plot(Sigma_log, ssa, label = 'Spectral Similarity', linewidth = 1, color='black')

plt.scatter(Sigma_log, nsa, s=5, marker = "*", color='blue')
plt.plot(Sigma_log, nsa, label = 'Normalized Sensitivity', linewidth = 1, color='blue')


plt.xlabel('sigma')
plt.ylabel('linearity metrics')
plt.legend()
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')

# %%
plt.scatter(Sigma_log, taa, s=5, marker = "*", color='orange')
plt.plot(Sigma_log, taa, label = 'thresh Alignment', linewidth = 1, color='orange')

plt.scatter(Sigma_log, tkmaa/10, s=5, marker = "*", color='yellow')
plt.plot(Sigma_log, tkmaa/10, label = 'trans_k_m Alignment', linewidth = 1, color='yellow')

plt.xlabel('sigma')
plt.ylabel('linearity metrics')
plt.legend()
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')

# %%
plt.scatter(Sigma_log, tkjaa, s=5, marker = "*", color='pink')
plt.plot(Sigma_log, tkjaa, label = 'trans_k_j Alignment', linewidth = 1, color='pink')

plt.scatter(Sigma_log, trjaa, s=5, marker = "*", color='brown')
plt.plot(Sigma_log, trjaa, label = 'trans_r_j Alignment', linewidth = 1, color='brown')

plt.scatter(Sigma_log, ajaa, s=5, marker = "*", color='olive')
plt.plot(Sigma_log, ajaa, label = 'a_j Alignment', linewidth = 1, color='olive')

plt.scatter(Sigma_log, ttaraa, s=5, marker = "*", color='cyan')
plt.plot(Sigma_log, ttaraa, label = 'transform_to_asc_r alignment', linewidth = 1, color='cyan')


plt.xlabel('sigma')
plt.ylabel('linearity metrics')
plt.legend()
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')

# %%
representation_alignment_ave_1 = []
representation_alignment_ave_2 = []
output_weight_alignment_ave = []
weight_matrix_alignment_ave = []
spectral_similarity_ave = []
normalized_sensitivity_ave = []
thresh_alignment_ave = []
trans_k_m_alignment_ave = []
trans_k_j_alignment_ave = []
trans_r_j_alignment_ave = []
a_j_alignment_ave = []
transform_to_asc_r_alignment_ave = []

# %%
Sigma_log = np.genfromtxt('./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_0_Sigma.csv', delimiter=',')
Sigma_log = Sigma_log/10.0

# %%
for Average in range(0, 9, 1):
    representation_alignment_log_1 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_RA_1.csv', delimiter=',')
    representation_alignment_log_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_RA_2.csv', delimiter=',')
    weight_matrix_alignment_log =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_WMA.csv', delimiter=',')
    output_weight_alignment_log =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_OWA.csv', delimiter=',')
    spectral_similarity_log =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_SS.csv', delimiter=',')
    normalized_sensitivity_log =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_NS.csv', delimiter=',')
    trans_k_j_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_TKJA.csv', delimiter=',')
    trans_r_j_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_TRJA.csv', delimiter=',')
    a_j_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_AJA.csv', delimiter=',')
    thresh_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_TA.csv', delimiter=',')
    trans_k_m_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_TKMA.csv', delimiter=',')
    transform_to_asc_r_alignment_log = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_TTARA.csv', delimiter=',')
    
    representation_alignment_ave_1.append(representation_alignment_log_1)
    representation_alignment_ave_2.append(representation_alignment_log_2)
    output_weight_alignment_ave.append(output_weight_alignment_log)
    weight_matrix_alignment_ave.append(weight_matrix_alignment_log)
    spectral_similarity_ave.append(spectral_similarity_log)
    normalized_sensitivity_ave.append(normalized_sensitivity_log)
    thresh_alignment_ave.append(thresh_alignment_log)
    trans_k_m_alignment_ave.append(trans_k_m_alignment_log)
    trans_k_j_alignment_ave.append(trans_k_j_alignment_log)
    trans_r_j_alignment_ave.append(trans_r_j_alignment_log)
    a_j_alignment_ave.append(a_j_alignment_log)
    transform_to_asc_r_alignment_ave.append(transform_to_asc_r_alignment_log)

# %%
raa_1 = representation_alignment_ave_1
raa_2 = representation_alignment_ave_2
owaa = output_weight_alignment_ave
wmaa = weight_matrix_alignment_ave
ssa = spectral_similarity_ave
nsa = normalized_sensitivity_ave
taa = thresh_alignment_ave
tkmaa = trans_k_m_alignment_ave
tkjaa = trans_k_j_alignment_ave
trjaa = trans_r_j_alignment_ave
ajaa = a_j_alignment_ave
ttaraa = transform_to_asc_r_alignment_ave

raa_1 = np.mean(raa_1, axis=0)
raa_2 = np.mean(raa_2, axis=0)
owaa = np.mean(owaa, axis=0)
wmaa = np.mean(wmaa, axis=0)
ssa = np.mean(ssa, axis=0)
nsa = np.mean(nsa, axis=0)
taa = np.mean(taa, axis=0)
tkmaa = np.mean(tkmaa, axis=0)
tkjaa = np.mean(tkjaa, axis=0)
trjaa = np.mean(trjaa, axis=0)
ajaa = np.mean(ajaa, axis=0)
ttaraa = np.mean(ttaraa, axis=0)

# %%
plt.scatter(Sigma_log, raa_1, s=5, marker = "*", color='green')
plt.plot(Sigma_log, raa_1, label = 'Representation Similarity_1', linewidth = 1, color='green')

#plt.scatter(Sigma_log, raa_2, s=5, marker = "*", color='purple')
#plt.plot(Sigma_log, raa_2, label = 'Representation Similarity_2', linewidth = 1, color='purple')

plt.scatter(Sigma_log, owaa/100, s=5, marker = "*", color='gray')
plt.plot(Sigma_log, owaa/100, label = 'Linear Weight Alignment', linewidth = 1, color='gray')

plt.scatter(Sigma_log, wmaa/100, s=5, marker = "*", color='red')
plt.plot(Sigma_log, wmaa/100, label = 'Weight Matrix Alignment', linewidth = 1, color='red')

plt.scatter(Sigma_log, ssa, s=5, marker = "*", color='black')
plt.plot(Sigma_log, ssa, label = 'Spectral Similarity', linewidth = 1, color='black')

plt.scatter(Sigma_log, nsa, s=5, marker = "*", color='blue')
plt.plot(Sigma_log, nsa, label = 'Normalized Sensitivity', linewidth = 1, color='blue')

plt.xlabel('sigma')
plt.ylabel('linearity metrics')
plt.legend()
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')

# %%
plt.scatter(Sigma_log, taa, s=5, marker = "*", color='orange')
plt.plot(Sigma_log, taa, label = 'thresh Alignment', linewidth = 1, color='orange')

plt.scatter(Sigma_log, tkmaa, s=5, marker = "*", color='yellow')
plt.plot(Sigma_log, tkmaa, label = 'trans_k_m Alignment', linewidth = 1, color='yellow')


plt.xlabel('sigma')
plt.ylabel('linearity metrics')
plt.legend()
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')

# %%
plt.scatter(Sigma_log, tkjaa, s=5, marker = "*", color='pink')
plt.plot(Sigma_log, tkjaa, label = 'trans_k_j Alignment', linewidth = 1, color='pink')

plt.scatter(Sigma_log, trjaa, s=5, marker = "*", color='brown')
plt.plot(Sigma_log, trjaa, label = 'trans_r_j Alignment', linewidth = 1, color='brown')

plt.scatter(Sigma_log, ajaa, s=5, marker = "*", color='olive')
plt.plot(Sigma_log, ajaa, label = 'a_j Alignment', linewidth = 1, color='olive')

plt.scatter(Sigma_log, ttaraa, s=5, marker = "*", color='cyan')
plt.plot(Sigma_log, ttaraa, label = 'transform_to_asc_r alignment', linewidth = 1, color='cyan')


plt.xlabel('sigma')
plt.ylabel('linearity metrics')
plt.legend()
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')

# %%
representation_alignment_ave_1_1 = []
representation_alignment_ave_2_1 = []
output_weight_alignment_ave_1 = []
weight_matrix_alignment_ave_1 = []
spectral_similarity_ave_1 = []
normalized_sensitivity_ave_1 = []
thresh_alignment_ave_1 = []
trans_k_m_alignment_ave_1 = []
trans_k_j_alignment_ave_1 = []
trans_r_j_alignment_ave_1 = []
a_j_alignment_ave_1 = []
transform_to_asc_r_alignment_ave_1 = []

representation_alignment_ave_1_2 = []
representation_alignment_ave_2_2 = []
output_weight_alignment_ave_2 = []
weight_matrix_alignment_ave_2 = []
spectral_similarity_ave_2 = []
normalized_sensitivity_ave_2 = []
thresh_alignment_ave_2 = []
trans_k_m_alignment_ave_2 = []
trans_k_j_alignment_ave_2 = []
trans_r_j_alignment_ave_2 = []
a_j_alignment_ave_2 = []
transform_to_asc_r_alignment_ave_2 = []

# %%
Sigma_log = np.genfromtxt('./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_0_Sigma.csv', delimiter=',')
Sigma_log = Sigma_log/10.0

# %%
for Average in range(0, 9, 1):
    representation_alignment_log_1_1 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_RA_1.csv', delimiter=',')
    representation_alignment_log_2_1 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_RA_2.csv', delimiter=',')
    weight_matrix_alignment_log_1 =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_WMA.csv', delimiter=',')
    output_weight_alignment_log_1 =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_OWA.csv', delimiter=',')
    spectral_similarity_log_1 =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_SS.csv', delimiter=',')
    normalized_sensitivity_log_1 =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_NS.csv', delimiter=',')
    trans_k_j_alignment_log_1 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_TKJA.csv', delimiter=',')
    trans_r_j_alignment_log_1 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_TRJA.csv', delimiter=',')
    a_j_alignment_log_1 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_AJA.csv', delimiter=',')
    thresh_alignment_log_1 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_TA.csv', delimiter=',')
    trans_k_m_alignment_log_1 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_TKMA.csv', delimiter=',')
    transform_to_asc_r_alignment_log_1 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_TTARA.csv', delimiter=',')
    representation_alignment_ave_1_1.append(representation_alignment_log_1_1)
    representation_alignment_ave_2_1.append(representation_alignment_log_2_1)
    output_weight_alignment_ave_1.append(output_weight_alignment_log_1)
    weight_matrix_alignment_ave_1.append(weight_matrix_alignment_log_1)
    spectral_similarity_ave_1.append(spectral_similarity_log_1)
    normalized_sensitivity_ave_1.append(normalized_sensitivity_log_1)
    thresh_alignment_ave_1.append(thresh_alignment_log_1)
    trans_k_m_alignment_ave_1.append(trans_k_m_alignment_log_1)
    trans_k_j_alignment_ave_1.append(trans_k_j_alignment_log_1)
    trans_r_j_alignment_ave_1.append(trans_r_j_alignment_log_1)
    a_j_alignment_ave_1.append(a_j_alignment_log_1)
    transform_to_asc_r_alignment_ave_1.append(transform_to_asc_r_alignment_log_1)

    representation_alignment_log_1_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_RA_1.csv', delimiter=',')
    representation_alignment_log_2_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_RA_2.csv', delimiter=',')
    weight_matrix_alignment_log_2 =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_WMA.csv', delimiter=',')
    output_weight_alignment_log_2 =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_OWA.csv', delimiter=',')
    spectral_similarity_log_2 =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_SS.csv', delimiter=',')
    normalized_sensitivity_log_2 =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_NS.csv', delimiter=',')
    trans_k_j_alignment_log_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_TKJA.csv', delimiter=',')
    trans_r_j_alignment_log_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_TRJA.csv', delimiter=',')
    a_j_alignment_log_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_AJA.csv', delimiter=',')
    thresh_alignment_log_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_TA.csv', delimiter=',')
    trans_k_m_alignment_log_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_TKMA.csv', delimiter=',')
    transform_to_asc_r_alignment_log_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_TTARA.csv', delimiter=',')
    
    representation_alignment_ave_1_2.append(representation_alignment_log_1_2)
    representation_alignment_ave_2_2.append(representation_alignment_log_2_2)
    output_weight_alignment_ave_2.append(output_weight_alignment_log_2)
    weight_matrix_alignment_ave_2.append(weight_matrix_alignment_log_2)
    spectral_similarity_ave_2.append(spectral_similarity_log_2)
    normalized_sensitivity_ave_2.append(normalized_sensitivity_log_2)
    thresh_alignment_ave_2.append(thresh_alignment_log_2)
    trans_k_m_alignment_ave_2.append(trans_k_m_alignment_log_2)
    trans_k_j_alignment_ave_2.append(trans_k_j_alignment_log_2)
    trans_r_j_alignment_ave_2.append(trans_r_j_alignment_log_2)
    a_j_alignment_ave_2.append(a_j_alignment_log_2)
    transform_to_asc_r_alignment_ave_2.append(transform_to_asc_r_alignment_log_2)

# %%
raa_1_1 = representation_alignment_ave_1_1
raa_2_1 = representation_alignment_ave_2_1
owaa_1 = output_weight_alignment_ave_1
wmaa_1 = weight_matrix_alignment_ave_1
ssa_1 = spectral_similarity_ave_1
nsa_1 = normalized_sensitivity_ave_1
taa_1 = thresh_alignment_ave_1
tkmaa_1 = trans_k_m_alignment_ave_1
tkjaa_1 = trans_k_j_alignment_ave_1
trjaa_1 = trans_r_j_alignment_ave_1
ajaa_1 = a_j_alignment_ave_1
ttaraa_1 = transform_to_asc_r_alignment_ave_1

raa_1_1 = np.mean(raa_1_1, axis=0)
raa_2_1 = np.mean(raa_2_1, axis=0)
owaa_1 = np.mean(owaa_1, axis=0)
wmaa_1 = np.mean(wmaa_1, axis=0)
ssa_1 = np.mean(ssa_1, axis=0)
nsa_1 = np.mean(nsa_1, axis=0)
taa_1 = np.mean(taa_1, axis=0)
tkmaa_1 = np.mean(tkmaa_1, axis=0)
tkjaa_1 = np.mean(tkjaa_1, axis=0)
trjaa_1 = np.mean(trjaa_1, axis=0)
ajaa_1 = np.mean(ajaa_1, axis=0)
ttaraa_1 = np.mean(ttaraa_1, axis=0)

raa_1_2 = representation_alignment_ave_1_2
raa_2_2 = representation_alignment_ave_2_2
owaa_2 = output_weight_alignment_ave_2
wmaa_2 = weight_matrix_alignment_ave_2
ssa_2 = spectral_similarity_ave_2
nsa_2 = normalized_sensitivity_ave_2
taa_2 = thresh_alignment_ave_2
tkmaa_2 = trans_k_m_alignment_ave_2
tkjaa_2 = trans_k_j_alignment_ave_2
trjaa_2 = trans_r_j_alignment_ave_2
ajaa_2 = a_j_alignment_ave_2
ttaraa_2 = transform_to_asc_r_alignment_ave_2

raa_1_2 = np.mean(raa_1_2, axis=0)
raa_2_2 = np.mean(raa_2_2, axis=0)
owaa_2 = np.mean(owaa_2, axis=0)
wmaa_2 = np.mean(wmaa_2, axis=0)
ssa_2 = np.mean(ssa_2, axis=0)
nsa_2 = np.mean(nsa_2, axis=0)
taa_2 = np.mean(taa_2, axis=0)
tkmaa_2 = np.mean(tkmaa_2, axis=0)
tkjaa_2 = np.mean(tkjaa_2, axis=0)
trjaa_2 = np.mean(trjaa_2, axis=0)
ajaa_2 = np.mean(ajaa_2, axis=0)
ttaraa_2 = np.mean(ttaraa_2, axis=0)

# %%
#plt.scatter(Sigma_log, raa_1_1, s=5, marker = "*", color='green')
#plt.plot(Sigma_log, raa_1_1, label = 'Representation Similarity_1 256', linewidth = 1, color='green')

#plt.scatter(Sigma_log, raa_2_1, s=5, marker = "*", color='green')
#plt.plot(Sigma_log, raa_2_1, label = 'Representation Similarity_2 256', linewidth = 1, color='green')

plt.scatter(Sigma_log, owaa_1/100, s=5, marker = "*", color='green')
plt.plot(Sigma_log, owaa_1/100, label = 'Output Weight Alignment 256', linewidth = 1, color='green')

plt.scatter(Sigma_log, wmaa_1/100, s=5, marker = "*", color='green')
plt.plot(Sigma_log, wmaa_1/100, label = 'Weight Matrix Alignment 256', linewidth = 1, color='green')
'''
plt.scatter(Sigma_log, ssa_1, s=5, marker = "*", color='green')
plt.plot(Sigma_log, ssa_1, label = 'Spectral Similarity 256', linewidth = 1, color='green')

plt.scatter(Sigma_log, nsa_1, s=5, marker = "*", color='green')
plt.plot(Sigma_log, nsa_1, label = 'Normalized Sensitivity 256', linewidth = 1, color='green')
'''



#plt.scatter(Sigma_log, raa_1_2, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, raa_1_2, label = 'Representation Similarity_1 1024', linewidth = 1, color='red')

#plt.scatter(Sigma_log, raa_2_2, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, raa_2_2, label = 'Representation Similarity_2 1024', linewidth = 1, color='red')

plt.scatter(Sigma_log, owaa_2/100, s=5, marker = "*", color='red')
plt.plot(Sigma_log, owaa_2/100, label = 'Linear Weight Alignment 1024', linewidth = 1, color='red')

plt.scatter(Sigma_log, wmaa_2/100, s=5, marker = "*", color='red')
plt.plot(Sigma_log, wmaa_2/100, label = 'Weight Matrix Alignment 1024', linewidth = 1, color='red')
'''
plt.scatter(Sigma_log, ssa_2, s=5, marker = "*", color='red')
plt.plot(Sigma_log, ssa_2, label = 'Spectral Similarity 1024', linewidth = 1, color='red')

plt.scatter(Sigma_log, nsa_2, s=5, marker = "*", color='red')
plt.plot(Sigma_log, nsa_2, label = 'Normalized Sensitivity 1024', linewidth = 1, color='red')
'''





#plt.scatter(Sigma_log, taa_1/100, s=5, marker = "*", color='green')
#plt.plot(Sigma_log, taa_1/100, label = 'thresh Alignment 256', linewidth = 1, color='green')

#plt.scatter(Sigma_log, tkmaa_1/100, s=5, marker = "*", color='green')
#plt.plot(Sigma_log, tkmaa_1/100, label = 'trans_k_m Alignment 256', linewidth = 1, color='green')

'''
plt.scatter(Sigma_log, tkjaa_1, s=5, marker = "*", color='pink')
plt.plot(Sigma_log, tkjaa_1, label = 'trans_k_j Alignment 256', linewidth = 1, color='pink')

plt.scatter(Sigma_log, trjaa_1, s=5, marker = "*", color='brown')
plt.plot(Sigma_log, trjaa_1, label = 'trans_r_j Alignment 256', linewidth = 1, color='brown')

plt.scatter(Sigma_log, ajaa_1, s=5, marker = "*", color='olive')
plt.plot(Sigma_log, ajaa_1, label = 'a_j Alignment 256', linewidth = 1, color='olive')

plt.scatter(Sigma_log, ttaraa_1, s=5, marker = "*", color='cyan')
plt.plot(Sigma_log, ttaraa_1, label = 'transform_to_asc_r alignment 256', linewidth = 1, color='cyan')
'''





#plt.scatter(Sigma_log, taa_2/100, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, taa_2/100, label = 'thresh Alignment 1024', linewidth = 1, color='red')

#plt.scatter(Sigma_log, tkmaa_2/100, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, tkmaa_2/100, label = 'trans_k_m Alignment 1024', linewidth = 1, color='red')

'''
plt.scatter(Sigma_log, tkjaa_2, s=5, marker = "*", color='pink')
plt.plot(Sigma_log, tkjaa_2, label = 'trans_k_j Alignment 1024', linewidth = 1, color='pink')

plt.scatter(Sigma_log, trjaa_2, s=5, marker = "*", color='brown')
plt.plot(Sigma_log, trjaa_2, label = 'trans_r_j Alignment 1024', linewidth = 1, color='brown')

plt.scatter(Sigma_log, ajaa_2, s=5, marker = "*", color='olive')
plt.plot(Sigma_log, ajaa_2, label = 'a_j Alignment 1024', linewidth = 1, color='olive')

plt.scatter(Sigma_log, ttaraa_2, s=5, marker = "*", color='cyan')
plt.plot(Sigma_log, ttaraa_2, label = 'transform_to_asc_r alignment 1024', linewidth = 1, color='cyan')
'''


plt.ylim(0, 1) 
plt.xlabel('sigma')
plt.ylabel('linearity metrics')
plt.legend()
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')

# %%
representation_alignment_ave_1_1 = []
representation_alignment_ave_2_1 = []
output_weight_alignment_ave_1 = []
weight_matrix_alignment_ave_1 = []
spectral_similarity_ave_1 = []
normalized_sensitivity_ave_1 = []
thresh_alignment_ave_1 = []
trans_k_m_alignment_ave_1 = []
trans_k_j_alignment_ave_1 = []
trans_r_j_alignment_ave_1 = []
a_j_alignment_ave_1 = []
transform_to_asc_r_alignment_ave_1 = []

representation_alignment_ave_1_2 = []
representation_alignment_ave_2_2 = []
output_weight_alignment_ave_2 = []
weight_matrix_alignment_ave_2 = []
spectral_similarity_ave_2 = []
normalized_sensitivity_ave_2 = []
thresh_alignment_ave_2 = []
trans_k_m_alignment_ave_2 = []
trans_k_j_alignment_ave_2 = []
trans_r_j_alignment_ave_2 = []
a_j_alignment_ave_2 = []
transform_to_asc_r_alignment_ave_2 = []

# %%
Sigma_log = np.genfromtxt('./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_0_Sigma.csv', delimiter=',')
Sigma_log = Sigma_log/10.0

# %%
for Average in range(0, 5, 1):
    representation_alignment_log_1_1 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_RA_1.csv', delimiter=',')
    representation_alignment_log_2_1 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_RA_2.csv', delimiter=',')
    weight_matrix_alignment_log_1 =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_WMA.csv', delimiter=',')
    output_weight_alignment_log_1 =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_OWA.csv', delimiter=',')
    spectral_similarity_log_1 =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_SS.csv', delimiter=',')
    normalized_sensitivity_log_1 =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_NS.csv', delimiter=',')
    trans_k_j_alignment_log_1 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_TKJA.csv', delimiter=',')
    trans_r_j_alignment_log_1 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_TRJA.csv', delimiter=',')
    a_j_alignment_log_1 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_AJA.csv', delimiter=',')
    thresh_alignment_log_1 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_TA.csv', delimiter=',')
    trans_k_m_alignment_log_1 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_TKMA.csv', delimiter=',')
    transform_to_asc_r_alignment_log_1 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_27/glifr_lheta_{Average}_TTARA.csv', delimiter=',')
    representation_alignment_ave_1_1.append(representation_alignment_log_1_1)
    representation_alignment_ave_2_1.append(representation_alignment_log_2_1)
    output_weight_alignment_ave_1.append(output_weight_alignment_log_1)
    weight_matrix_alignment_ave_1.append(weight_matrix_alignment_log_1)
    spectral_similarity_ave_1.append(spectral_similarity_log_1)
    normalized_sensitivity_ave_1.append(normalized_sensitivity_log_1)
    thresh_alignment_ave_1.append(thresh_alignment_log_1)
    trans_k_m_alignment_ave_1.append(trans_k_m_alignment_log_1)
    trans_k_j_alignment_ave_1.append(trans_k_j_alignment_log_1)
    trans_r_j_alignment_ave_1.append(trans_r_j_alignment_log_1)
    a_j_alignment_ave_1.append(a_j_alignment_log_1)
    transform_to_asc_r_alignment_ave_1.append(transform_to_asc_r_alignment_log_1)

    representation_alignment_log_1_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_RA_1.csv', delimiter=',')
    representation_alignment_log_2_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_RA_2.csv', delimiter=',')
    weight_matrix_alignment_log_2 =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_WMA.csv', delimiter=',')
    output_weight_alignment_log_2 =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_OWA.csv', delimiter=',')
    spectral_similarity_log_2 =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_SS.csv', delimiter=',')
    normalized_sensitivity_log_2 =  np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_NS.csv', delimiter=',')
    trans_k_j_alignment_log_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_TKJA.csv', delimiter=',')
    trans_r_j_alignment_log_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_TRJA.csv', delimiter=',')
    a_j_alignment_log_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_AJA.csv', delimiter=',')
    thresh_alignment_log_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_TA.csv', delimiter=',')
    trans_k_m_alignment_log_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_TKMA.csv', delimiter=',')
    transform_to_asc_r_alignment_log_2 = np.genfromtxt(f'./analysis/sigma_v/lheta_lmnist_28/glifr_lheta_{Average}_TTARA.csv', delimiter=',')
    
    representation_alignment_ave_1_2.append(representation_alignment_log_1_2)
    representation_alignment_ave_2_2.append(representation_alignment_log_2_2)
    output_weight_alignment_ave_2.append(output_weight_alignment_log_2)
    weight_matrix_alignment_ave_2.append(weight_matrix_alignment_log_2)
    spectral_similarity_ave_2.append(spectral_similarity_log_2)
    normalized_sensitivity_ave_2.append(normalized_sensitivity_log_2)
    thresh_alignment_ave_2.append(thresh_alignment_log_2)
    trans_k_m_alignment_ave_2.append(trans_k_m_alignment_log_2)
    trans_k_j_alignment_ave_2.append(trans_k_j_alignment_log_2)
    trans_r_j_alignment_ave_2.append(trans_r_j_alignment_log_2)
    a_j_alignment_ave_2.append(a_j_alignment_log_2)
    transform_to_asc_r_alignment_ave_2.append(transform_to_asc_r_alignment_log_2)

# %%
raa_1_1 = representation_alignment_ave_1_1
raa_2_1 = representation_alignment_ave_2_1
owaa_1 = output_weight_alignment_ave_1
wmaa_1 = weight_matrix_alignment_ave_1
ssa_1 = spectral_similarity_ave_1
nsa_1 = normalized_sensitivity_ave_1
taa_1 = thresh_alignment_ave_1
tkmaa_1 = trans_k_m_alignment_ave_1
tkjaa_1 = trans_k_j_alignment_ave_1
trjaa_1 = trans_r_j_alignment_ave_1
ajaa_1 = a_j_alignment_ave_1
ttaraa_1 = transform_to_asc_r_alignment_ave_1

raa_1_1 = np.mean(raa_1_1, axis=0)
raa_2_1 = np.mean(raa_2_1, axis=0)
owaa_1 = np.mean(owaa_1, axis=0)
wmaa_1 = np.mean(wmaa_1, axis=0)
ssa_1 = np.mean(ssa_1, axis=0)
nsa_1 = np.mean(nsa_1, axis=0)
taa_1 = np.mean(taa_1, axis=0)
tkmaa_1 = np.mean(tkmaa_1, axis=0)
tkjaa_1 = np.mean(tkjaa_1, axis=0)
trjaa_1 = np.mean(trjaa_1, axis=0)
ajaa_1 = np.mean(ajaa_1, axis=0)
ttaraa_1 = np.mean(ttaraa_1, axis=0)

raa_1_2 = representation_alignment_ave_1_2
raa_2_2 = representation_alignment_ave_2_2
owaa_2 = output_weight_alignment_ave_2
wmaa_2 = weight_matrix_alignment_ave_2
ssa_2 = spectral_similarity_ave_2
nsa_2 = normalized_sensitivity_ave_2
taa_2 = thresh_alignment_ave_2
tkmaa_2 = trans_k_m_alignment_ave_2
tkjaa_2 = trans_k_j_alignment_ave_2
trjaa_2 = trans_r_j_alignment_ave_2
ajaa_2 = a_j_alignment_ave_2
ttaraa_2 = transform_to_asc_r_alignment_ave_2

raa_1_2 = np.mean(raa_1_2, axis=0)
raa_2_2 = np.mean(raa_2_2, axis=0)
owaa_2 = np.mean(owaa_2, axis=0)
wmaa_2 = np.mean(wmaa_2, axis=0)
ssa_2 = np.mean(ssa_2, axis=0)
nsa_2 = np.mean(nsa_2, axis=0)
taa_2 = np.mean(taa_2, axis=0)
tkmaa_2 = np.mean(tkmaa_2, axis=0)
tkjaa_2 = np.mean(tkjaa_2, axis=0)
trjaa_2 = np.mean(trjaa_2, axis=0)
ajaa_2 = np.mean(ajaa_2, axis=0)
ttaraa_2 = np.mean(ttaraa_2, axis=0)

# %%
#plt.scatter(Sigma_log, raa_1_1, s=5, marker = "*", color='green')
#plt.plot(Sigma_log, raa_1_1, label = 'Representation Similarity_1 256', linewidth = 1, color='green')

#plt.scatter(Sigma_log, raa_2_1, s=5, marker = "*", color='green')
#plt.plot(Sigma_log, raa_2_1, label = 'Representation Similarity_2 256', linewidth = 1, color='green')

#plt.scatter(Sigma_log, owaa_1/100, s=5, marker = "*", color='green')
#plt.plot(Sigma_log, owaa_1/100, label = 'Output Weight Alignment 256', linewidth = 1, color='green')

plt.scatter(Sigma_log, wmaa_1/100, s=5, marker = "*", color='green')
plt.plot(Sigma_log, wmaa_1/100, label = 'Weight Matrix Alignment 256', linewidth = 1, color='green')
'''
plt.scatter(Sigma_log, ssa_1, s=5, marker = "*", color='green')
plt.plot(Sigma_log, ssa_1, label = 'Spectral Similarity 256', linewidth = 1, color='green')

plt.scatter(Sigma_log, nsa_1, s=5, marker = "*", color='green')
plt.plot(Sigma_log, nsa_1, label = 'Normalized Sensitivity 256', linewidth = 1, color='green')
'''



#plt.scatter(Sigma_log, raa_1_2, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, raa_1_2, label = 'Representation Similarity_1 1024', linewidth = 1, color='red')

#plt.scatter(Sigma_log, raa_2_2, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, raa_2_2, label = 'Representation Similarity_2 1024', linewidth = 1, color='red')

#plt.scatter(Sigma_log, owaa_2/100, s=5, marker = "*", color='red')
#plt.plot(Sigma_log, owaa_2/100, label = 'Output Weight Alignment 1024', linewidth = 1, color='red')

plt.scatter(Sigma_log, wmaa_2/100, s=5, marker = "*", color='red')
plt.plot(Sigma_log, wmaa_2/100, label = 'Weight Matrix Alignment 1024', linewidth = 1, color='red')
'''
plt.scatter(Sigma_log, ssa_2, s=5, marker = "*", color='red')
plt.plot(Sigma_log, ssa_2, label = 'Spectral Similarity 1024', linewidth = 1, color='red')

plt.scatter(Sigma_log, nsa_2, s=5, marker = "*", color='red')
plt.plot(Sigma_log, nsa_2, label = 'Normalized Sensitivity 1024', linewidth = 1, color='red')
'''





plt.scatter(Sigma_log, taa_1/100, s=5, marker = "*", color='green')
plt.plot(Sigma_log, taa_1/100, label = 'thresh Alignment 256', linewidth = 1, color='green')

plt.scatter(Sigma_log, tkmaa_1/100, s=5, marker = "*", color='green')
plt.plot(Sigma_log, tkmaa_1/100, label = 'trans_k_m Alignment 256', linewidth = 1, color='green')

'''
plt.scatter(Sigma_log, tkjaa_1, s=5, marker = "*", color='pink')
plt.plot(Sigma_log, tkjaa_1, label = 'trans_k_j Alignment 256', linewidth = 1, color='pink')

plt.scatter(Sigma_log, trjaa_1, s=5, marker = "*", color='brown')
plt.plot(Sigma_log, trjaa_1, label = 'trans_r_j Alignment 256', linewidth = 1, color='brown')

plt.scatter(Sigma_log, ajaa_1, s=5, marker = "*", color='olive')
plt.plot(Sigma_log, ajaa_1, label = 'a_j Alignment 256', linewidth = 1, color='olive')

plt.scatter(Sigma_log, ttaraa_1, s=5, marker = "*", color='cyan')
plt.plot(Sigma_log, ttaraa_1, label = 'transform_to_asc_r alignment 256', linewidth = 1, color='cyan')
'''





plt.scatter(Sigma_log, taa_2/100, s=5, marker = "*", color='red')
plt.plot(Sigma_log, taa_2/100, label = 'thresh Alignment 1024', linewidth = 1, color='red')

plt.scatter(Sigma_log, tkmaa_2/100, s=5, marker = "*", color='red')
plt.plot(Sigma_log, tkmaa_2/100, label = 'trans_k_m Alignment 1024', linewidth = 1, color='red')

'''
plt.scatter(Sigma_log, tkjaa_2, s=5, marker = "*", color='pink')
plt.plot(Sigma_log, tkjaa_2, label = 'trans_k_j Alignment 1024', linewidth = 1, color='pink')

plt.scatter(Sigma_log, trjaa_2, s=5, marker = "*", color='brown')
plt.plot(Sigma_log, trjaa_2, label = 'trans_r_j Alignment 1024', linewidth = 1, color='brown')

plt.scatter(Sigma_log, ajaa_2, s=5, marker = "*", color='olive')
plt.plot(Sigma_log, ajaa_2, label = 'a_j Alignment 1024', linewidth = 1, color='olive')

plt.scatter(Sigma_log, ttaraa_2, s=5, marker = "*", color='cyan')
plt.plot(Sigma_log, ttaraa_2, label = 'transform_to_asc_r alignment 1024', linewidth = 1, color='cyan')
'''


plt.ylim(0, 1) 
plt.xlabel('sigma')
plt.ylabel('linearity metrics')
plt.legend()
plt.title("Rich and Lazy")
# Out:
# Text(0.5, 1.0, 'Rich and Lazy')
